# %% [markdown]
# # Lab-4:
# In this lab, we will examine some classifiers and the regularization concept in the classification problem.
# Also, we will see
#
# ### Objectives:
# 1. Lasso and Ridge
# 2. Naïve Bayes
# 3. KNN
# 4. Cross Validation
#
# ---
# ## Lasso and Ridge
# Both models are the regularized forms of the linear regression.
# Lass with L1 regularization and Ridge with L2 regularization.
# Both act as a constraint region for the coeffeicients/weight, where they must reside in.
#
# ### Issues:
# 1. When to use Lasso?
# 2. When to use Ridge?
# 3. Since it is hard to decide the parameters influence, How we can decide which regularization? and decide the value of lambda?
#
# ### Loading Boston dataset
# Housing-Prices Values in Suburbs of Boston.

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

X, y = load_boston(return_X_y=True)
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=1/8, random_state=123)

# %% [markdown]
# ### Fitting both Lasso and Ridge
# Task:
#
# Fit two models: Lasso and Ridge -with the default alpha-.
# Then print their coefficients and notice the difference.

# %%
from sklearn.linear_model import Lasso, Ridge

lasso_model = Lasso()
ridge_model = Ridge()

lasso_model.fit(x_train, y_train)
ridge_model.fit(x_train, y_train)

print(lasso_model.intercept_)
print(lasso_model.coef_)

print(ridge_model.intercept_)
print(ridge_model.coef_)
# Out:
# 32.738785711984555
# [-6.29657633e-02  3.50956640e-02  0.00000000e+00  0.00000000e+00
#  -0.00000000e+00  2.26979134e+00  6.77955847e-04 -6.45065773e-01
#   1.93545727e-01 -1.35087027e-02 -6.45345873e-01  4.49042185e-03
#  -6.73150676e-01]
# 22.324375353555865
# [-1.11057981e-01  3.65852805e-02  4.69212854e-02  6.03824135e-01
#  -6.97460565e+00  5.11864285e+00 -2.69870227e-02 -1.22824280e+00
#   2.49139807e-01 -1.39899765e-02 -8.47813312e-01  6.95422088e-03
#  -4.68816487e-01]

# %% [markdown]
# Task:
# Let's try different values for alpha for Lasso regressor and plot the validation loss.

# %%
import matplotlib.pylab as plt
import numpy as np
from sklearn.metrics import mean_squared_error
# %matplotlib inline

alphas = [2.2, 2, 1.5, 1.3, 1.2, 1.1, 1, 0.3, 0.1]
losses = []
for alpha in alphas:
    # Write (5 lines): create a Lasso regressor with the alpha value.
    # Fit it to the training set, then get the prediction of the validation set (x_val).
    # calculate the mean sqaured error loss, then append it to the losses array
    lasso_model = Lasso(alpha).fit(x_train, y_train)
    y_pred = lasso_model.predict(x_val)
    mse = mean_squared_error(y_val, y_pred, squared=False)
    losses.append(mse)

plt.plot(alphas, losses)
plt.xlabel("alpha")
plt.ylabel("Mean squared error")
plt.show()

best_alpha = alphas[np.argmin(losses)]
print("Best value of alpha:", best_alpha)
# Out:
# Best value of alpha: 1.3

# %% [markdown]
# Measuring the loss on the testset with Lasso regressor with the best alpha.

# %%
lasso = Lasso(best_alpha)
lasso.fit(x_train, y_train)
y_pred = lasso.predict(x_test)
print("MSE on testset:", mean_squared_error(y_test, y_pred))
# Out:
# MSE on testset: 31.953762880829828

# %% [markdown]
# ## Loading the iris dataset
# Dataset of 3 types/classes of flowers with 4 features. Suitable for classification!

# %%
from sklearn.datasets import load_digits

X, y = load_digits(return_X_y=True)
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
# We will show why we didn't split a validation set.

# %% [markdown]
# ## Naïve Bayes
# We will use the Gaussian Naïve Bayes, that deals -as a assumption- with the continous features as gaussian variables to compute their probability.
#
# $$P(x_i|y) = \frac{1}{\sqrt{2\pi\sigma_y^2}}exp(-\frac{(x_i - \mu_y)^2}{2\sigma_y^2})$$
#
# While $\mu_y$ and $\sigma_y^2$ are the mean and the variance of the feature $i$ for class $y$.
#
# Note: The different naive Bayes classifiers differ mainly by the assumptions they make regarding the distribution of $P(x_i|y)$.
#
# ___
# What are the pros and cons of Naive bayes classifier?
# ___

# %% [markdown]
# Let's train a naive-bayes model and check the test accuracy.

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gauss_nb = GaussianNB()
gauss_nb.fit(x_train, y_train)
y_pred = gauss_nb.predict(x_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8777777777777778

# %% [markdown]
# ## K nearest neighbour classifier
# 1. What are the pros and cons of KNN?
#
# 2. To increase the variance of KNN model, should we increase or decrease the K?

# %% [markdown]
# ___
# Let's do the same with KNN classifier.
#
#
# Rescale the features first.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9722222222222222

# %% [markdown]
# Task: Let's tune the hyperparameter $n\_neighbors$ in the KNN classifier object using the cross-validation.
#
# ___
# ## Cross Validation
# Cross validation comes as an alternative for the validation set splitting.
#
# Note: that's why we didn't make a validation set.

# %%
from sklearn.model_selection import cross_val_score
import matplotlib.pylab as plt
import numpy as np
# %matplotlib inline

Ks = list(range(1, 20))
cv_scores = []
for K in Ks:
    knn = KNeighborsClassifier(n_neighbors=K)
    # Write 2 lines of code, one to compute the CV scores.
    # And another to calculate the average.
    scores = cross_val_score(knn, x_train, y_train, cv=7)
    avg_score = np.average(scores)
    # Task ends

    cv_scores.append(avg_score)

plt.plot(Ks, cv_scores)
plt.show()
print(cv_scores)
print("Best K:", Ks[np.argmax(cv_scores)])
# Out:
# [0.9735496092825006, 0.9652075369574777, 0.9735529921179934, 0.9721727952369676, 0.9721694124014749, 0.9700754372314874, 0.9679848448969927, 0.9700720543959946, 0.9700720543959946, 0.9686850918439837, 0.9700754372314874, 0.9659010182334834, 0.965904401068976, 0.9617232163999864, 0.9568519332904841, 0.9547613409559893, 0.9519874158519671, 0.9519840330164744, 0.9512871689049761]
# Best K: 3

# %% [markdown]
# In KNN classifier, there're several hyperparamters to tune, tuning them one by one is exhaustive approach.
# Let's try a better approach called GridSearchCV.
#
#
# ### GridSearchCV
# In GridSearch Cross-validation, you give different values for each hyperparamter and it will try all combinations for you.
# At the end, it will return the best combination of hyperparamters that got the best cross-validation score.
#
# Task:
# Use gridsearch to tune 3 hyperparameters:
#
# 1. $n\_neighbors$: [1, 2, . . ., 10]
# 2. $weights$: ['uniform', 'distance']
# 3. $metric$: ['euclidean', 'manhattan', 'chebyshev', 'cosine']
#
# Check this [link](https://scikit-learn.org/stable/auto_examples/model_selection/plot_grid_search_digits.html) for help.
#
# Then measure the accuracy on the testset.

# %%
from sklearn.model_selection import GridSearchCV

# Write 2 lines of code to run GridSearchCV with cv=7 to tune the above hyperparams.
neighbours = np.arange(1, 10, 2)
parameters = [{'n_neighbors': neighbours, 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan', 'chebyshev', 'cosine']}]

grid_search_clf = GridSearchCV(knn, parameters, cv = 7)
# Task ends here!

grid_search_clf.fit(x_train, y_train)
means = grid_search_clf.cv_results_['mean_test_score']
stds = grid_search_clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, grid_search_clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
        % (mean, std * 2, params))
print()
print("Best parameters set found on development set:")
print()
print(grid_search_clf.best_params_)

y_pred = grid_search_clf.predict(x_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.974 (+/-0.022) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'uniform'}
# 0.974 (+/-0.022) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'distance'}
# 0.974 (+/-0.021) for {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.975 (+/-0.027) for {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'distance'}
# 0.972 (+/-0.030) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.972 (+/-0.027) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# 0.968 (+/-0.027) for {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.970 (+/-0.025) for {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'distance'}
# 0.970 (+/-0.031) for {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.971 (+/-0.024) for {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'distance'}
# 0.982 (+/-0.016) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}
# 0.982 (+/-0.016) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
# 0.976 (+/-0.027) for {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.978 (+/-0.026) for {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
# 0.972 (+/-0.027) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.976 (+/-0.021) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# 0.971 (+/-0.027) for {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.974 (+/-0.024) for {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'distance'}
# 0.969 (+/-0.031) for {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.971 (+/-0.026) for {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'distance'}
# 0.935 (+/-0.026) for {'metric': 'chebyshev', 'n_neighbors': 1, 'weights': 'uniform'}
# 0.935 (+/-0.026) for {'metric': 'chebyshev', 'n_neighbors': 1, 'weights': 'distance'}
# 0.916 (+/-0.020) for {'metric': 'chebyshev', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.927 (+/-0.020) for {'metric': 'chebyshev', 'n_neighbors': 3, 'weights': 'distance'}
# 0.919 (+/-0.016) for {'metric': 'chebyshev', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.928 (+/-0.023) for {'metric': 'chebyshev', 'n_neighbors': 5, 'weights': 'distance'}
# 0.914 (+/-0.024) for {'metric': 'chebyshev', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.922 (+/-0.025) for {'metric': 'chebyshev', 'n_neighbors': 7, 'weights': 'distance'}
# 0.904 (+/-0.027) for {'metric': 'chebyshev', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.915 (+/-0.018) for {'metric': 'chebyshev', 'n_neighbors': 9, 'weights': 'distance'}
# 0.968 (+/-0.018) for {'metric': 'cosine', 'n_neighbors': 1, 'weights': 'uniform'}
# 0.968 (+/-0.018) for {'metric': 'cosine', 'n_neighbors': 1, 'weights': 'distance'}
# 0.962 (+/-0.026) for {'metric': 'cosine', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.964 (+/-0.031) for {'metric': 'cosine', 'n_neighbors': 3, 'weights': 'distance'}
# 0.960 (+/-0.024) for {'metric': 'cosine', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.964 (+/-0.024) for {'metric': 'cosine', 'n_neighbors': 5, 'weights': 'distance'}
# 0.959 (+/-0.019) for {'metric': 'cosine', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.961 (+/-0.015) for {'metric': 'cosine', 'n_neighbors': 7, 'weights': 'distance'}
# 0.959 (+/-0.023) for {'metric': 'cosine', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.961 (+/-0.018) for {'metric': 'cosine', 'n_neighbors': 9, 'weights': 'distance'}
#
# Best parameters set found on development set:
#
# {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}
# 0.975
